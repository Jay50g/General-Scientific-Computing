# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from scipy import *

# %%
x1=np.linspace(0,np.pi,100)

# %%
y1=np.sin(x1)+0.1*np.random.standard_normal(len(x1))

# %%
plt.plot(x1,y1,'r-')
plt.plot(x1,np.sin(x1),'b-',lw=3)

# %%
y1.sum()/len(y1)
# Out:
# 0.6319382545774922

# %%
2/np.pi
# Out:
# 0.6366197723675814

# %%
x2=sp.stats.unifrom.rvs(size=100)*np.pi
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 x2=sp.stats.unifrom.rvs(size=100)*np.pi
#
# AttributeError: module 'scipy.stats' has no attribute 'unifrom'

# %%
y2=np.sin(x2)+0.1*np.random.standard_normal(len(x2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 y2=np.sin(x2)+0.1*np.random.standard_normal(len(x2))
#
# NameError: name 'x2' is not defined

# %%
#y2.sum()/len(y2)

# %%
t=sp.stats.norm.rvs(loc=np.pi/2,scale=1,size=100)

# %%
a=plt.hist(t,bins=20,density='True')
plt.plot(x1,y1,'r-')

# %%
y=np.zeros(len(t))
for i in range(len(t)):
    if t[i]>0 and t[i]<np.pi:
        y[i]=np.sin(t[i])+0.1*np.random.standard_normal()

# %%
plt.plot(t,y,'r.')

# %%
y.sum()/len(y)
# Out:
# 0.5944530464506432
