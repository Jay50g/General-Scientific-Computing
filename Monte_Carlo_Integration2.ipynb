# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,np.pi,500)
y=np.sin(x)
t=np.linspace(0,np.pi,50000000)
yt=np.sin(t)

# %%
plt.plot(x,y,'r-')
#plt.plot(t,yt,'bo')

# %%
yt.sum()/len(yt)
# Out:
# 0.6366197596351854

# %%
2/np.pi
# Out:
# 0.6366197723675814
